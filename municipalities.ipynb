# %%
import osmnx as ox
# Out:
# c:\Users\Johan\Anaconda3\envs\gds_py\lib\site-packages\osmnx\projection.py:3: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
geometry = ox.geocode_to_gdf("Copenhagen, Denmark")

# %%
admin_boundaries = ox.geometries_from_place("Denmark", which_result=1, tags={"boundary": "administrative"})

# %%
admin_boundaries[admin_boundaries["admin_level"] == "7"]
# Out:
#                      admin_level alt_name:gl                  name name:am  \
# element_type osmid
# relation     2171069           7         NaN  Guldborgsund Kommune     NaN
#              2077580           7         NaN        Stevns Kommune     NaN
#              2171256           7         NaN   Vordingborg Kommune     NaN
#              2181377           7         NaN          Faxe Kommune     NaN
#              2181494           7         NaN       Næstved Kommune     NaN
# ...                          ...         ...                   ...     ...
#              1927247           7         NaN        Struer Kommune     NaN
#              1927494           7         NaN     Holstebro Kommune     NaN
#              2095234           7         NaN         Morsø Kommune     NaN
#              2930285           7         NaN       Thisted Kommune     NaN
#              1926825           7         NaN          Fanø Kommune     NaN
#
# ...
